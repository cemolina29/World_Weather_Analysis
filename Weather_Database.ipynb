# %%
# Import the dependencies.

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests

# %%
from citipy import citipy

# %%
# Import the API key.
from config1 import weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes in a list.
coordinates = list(lats_lngs)

# %%
#Create a list for holding the names of cities.
cities = []
#Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 775

# %%
# Import the requests library.
import requests

# Import the API key.
from config1 import weather_api_key

# Starting URL for Weather Map API Call, no city defined
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 100):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description=city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | kaitangata
# Processing Record 3 of Set 1 | oussouye
# Processing Record 4 of Set 1 | bang rakam
# Processing Record 5 of Set 1 | dikson
# Processing Record 6 of Set 1 | lieksa
# Processing Record 7 of Set 1 | saint-philippe
# Processing Record 8 of Set 1 | narsaq
# Processing Record 9 of Set 1 | sao gotardo
# Processing Record 10 of Set 1 | kodiak
# Processing Record 11 of Set 1 | cururupu
# Processing Record 12 of Set 1 | samarai
# Processing Record 13 of Set 1 | fairbanks
# Processing Record 14 of Set 1 | gimli
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | ko samui
# Processing Record 17 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 1 | dingle
# Processing Record 19 of Set 1 | port augusta
# Processing Record 20 of Set 1 | kapaa
# Processing Record 21 of Set 1 | zhezkazgan
# Processing Record 22 of Set 1 | port hardy
# Processing Record 23 of Set 1 | katsuura
# Processing Record 24 of Set 1 | hermanus
# Processing Record 25 of Set 1 | barrow
# Processing Record 26 of Set 1 | puerto ayora
# Processing Record 27 of Set 1 | nikolskoye
# Processing Record 28 of Set 1 | ahipara
# Processing Record 29 of Set 1 | victoria
# Processing Record 30 of Set 1 | ilulissat
# Processing Record 31 of Set 1 | rostaq
# City not found. Skipping...
# Processing Record 32 of Set 1 | waingapu
# Processing Record 33 of Set 1 | abu kamal
# Processing Record 34 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 1 | caravelas
# Processing Record 36 of Set 1 | vaini
# Processing Record 37 of Set 1 | cape town
# Processing Record 38 of Set 1 | uusikaupunki
# Processing Record 39 of Set 1 | busselton
# Processing Record 40 of Set 1 | esperance
# Processing Record 41 of Set 1 | eskilstuna
# Processing Record 42 of Set 1 | novyy oskol
# Processing Record 43 of Set 1 | riyadh
# Processing Record 44 of Set 1 | port alfred
# Processing Record 45 of Set 1 | tiksi
# Processing Record 46 of Set 1 | hilo
# Processing Record 47 of Set 1 | general roca
# Processing Record 48 of Set 1 | sibu
# Processing Record 49 of Set 1 | ginda
# Processing Record 50 of Set 1 | chuy
# Processing Record 51 of Set 1 | imeni telmana
# City not found. Skipping...
# Processing Record 52 of Set 1 | albany
# Processing Record 53 of Set 1 | samarinda
# Processing Record 54 of Set 1 | bluff
# Processing Record 55 of Set 1 | rikitea
# Processing Record 56 of Set 1 | suntar
# Processing Record 57 of Set 1 | marawi
# Processing Record 58 of Set 1 | ribeira grande
# Processing Record 59 of Set 1 | jamestown
# Processing Record 60 of Set 1 | mapiripan
# Processing Record 61 of Set 1 | yanan
# City not found. Skipping...
# Processing Record 62 of Set 1 | codrington
# Processing Record 63 of Set 1 | berezovyy
# Processing Record 64 of Set 1 | kudahuvadhoo
# Processing Record 65 of Set 1 | mataura
# Processing Record 66 of Set 1 | grenfell
# Processing Record 67 of Set 1 | brae
# Processing Record 68 of Set 1 | avarua
# Processing Record 69 of Set 1 | port lincoln
# Processing Record 70 of Set 1 | gladstone
# Processing Record 71 of Set 1 | ushuaia
# Processing Record 72 of Set 1 | alice town
# Processing Record 73 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 74 of Set 1 | saint george
# Processing Record 75 of Set 1 | komsomolskiy
# Processing Record 76 of Set 1 | dongsheng
# Processing Record 77 of Set 1 | new norfolk
# Processing Record 78 of Set 1 | bambous virieux
# Processing Record 79 of Set 1 | nouadhibou
# Processing Record 80 of Set 1 | port elizabeth
# Processing Record 81 of Set 1 | usinsk
# Processing Record 82 of Set 1 | lagoa
# Processing Record 83 of Set 1 | teya
# Processing Record 84 of Set 1 | mar del plata
# Processing Record 85 of Set 1 | glendive
# Processing Record 86 of Set 1 | batagay-alyta
# Processing Record 87 of Set 1 | lompoc
# Processing Record 88 of Set 1 | najran
# Processing Record 89 of Set 1 | meadow lake
# Processing Record 90 of Set 1 | qaanaaq
# Processing Record 91 of Set 1 | havelock
# Processing Record 92 of Set 1 | talnakh
# Processing Record 93 of Set 1 | provideniya
# Processing Record 94 of Set 1 | itoman
# Processing Record 95 of Set 1 | yulara
# Processing Record 96 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 97 of Set 1 | norman wells
# Processing Record 98 of Set 1 | saskylakh
# Processing Record 99 of Set 1 | priargunsk
# Processing Record 100 of Set 1 | east london
# Processing Record 1 of Set 2 | lata
# Processing Record 2 of Set 2 | tahe
# Processing Record 3 of Set 2 | upernavik
# Processing Record 4 of Set 2 | mount pleasant
# Processing Record 5 of Set 2 | laguna
# Processing Record 6 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 2 | atuona
# Processing Record 8 of Set 2 | calama
# Processing Record 9 of Set 2 | ilhabela
# Processing Record 10 of Set 2 | mahebourg
# Processing Record 11 of Set 2 | kachikau
# City not found. Skipping...
# Processing Record 12 of Set 2 | alugan
# Processing Record 13 of Set 2 | kyshtovka
# Processing Record 14 of Set 2 | tautira
# Processing Record 15 of Set 2 | pangnirtung
# Processing Record 16 of Set 2 | vardo
# Processing Record 17 of Set 2 | atar
# Processing Record 18 of Set 2 | yellowknife
# Processing Record 19 of Set 2 | talcahuano
# Processing Record 20 of Set 2 | vila velha
# Processing Record 21 of Set 2 | tuktoyaktuk
# Processing Record 22 of Set 2 | kavaratti
# Processing Record 23 of Set 2 | montrose
# Processing Record 24 of Set 2 | hangu
# Processing Record 25 of Set 2 | la rioja
# Processing Record 26 of Set 2 | roma
# Processing Record 27 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 2 | bara
# Processing Record 29 of Set 2 | praia
# Processing Record 30 of Set 2 | hobyo
# Processing Record 31 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 2 | north bend
# Processing Record 33 of Set 2 | aklavik
# Processing Record 34 of Set 2 | tecpan
# Processing Record 35 of Set 2 | verkhnyaya inta
# Processing Record 36 of Set 2 | cherskiy
# Processing Record 37 of Set 2 | sinnamary
# Processing Record 38 of Set 2 | hofn
# Processing Record 39 of Set 2 | tenenkou
# Processing Record 40 of Set 2 | coquimbo
# Processing Record 41 of Set 2 | tarbagatay
# Processing Record 42 of Set 2 | kruisfontein
# Processing Record 43 of Set 2 | chokurdakh
# Processing Record 44 of Set 2 | nagato
# Processing Record 45 of Set 2 | hasaki
# Processing Record 46 of Set 2 | kisanga
# Processing Record 47 of Set 2 | port-cartier
# Processing Record 48 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 2 | port-gentil
# Processing Record 50 of Set 2 | aswan
# Processing Record 1 of Set 3 | beringovskiy
# Processing Record 2 of Set 3 | guozhen
# Processing Record 3 of Set 3 | dehloran
# Processing Record 4 of Set 3 | verkh-usugli
# Processing Record 5 of Set 3 | margate
# Processing Record 6 of Set 3 | hithadhoo
# Processing Record 7 of Set 3 | boromlya
# Processing Record 8 of Set 3 | lebu
# Processing Record 9 of Set 3 | nsanje
# Processing Record 10 of Set 3 | shimoda
# Processing Record 11 of Set 3 | cabo san lucas
# Processing Record 12 of Set 3 | dohrighat
# Processing Record 13 of Set 3 | sao filipe
# Processing Record 14 of Set 3 | jalu
# Processing Record 15 of Set 3 | carnarvon
# Processing Record 16 of Set 3 | alice springs
# Processing Record 17 of Set 3 | paamiut
# Processing Record 18 of Set 3 | denpasar
# Processing Record 19 of Set 3 | safford
# Processing Record 20 of Set 3 | sedelnikovo
# City not found. Skipping...
# Processing Record 21 of Set 3 | tupik
# Processing Record 22 of Set 3 | senanga
# Processing Record 23 of Set 3 | carndonagh
# Processing Record 24 of Set 3 | nome
# Processing Record 25 of Set 3 | arraial do cabo
# Processing Record 26 of Set 3 | princeton
# Processing Record 27 of Set 3 | winnemucca
# Processing Record 28 of Set 3 | itaituba
# Processing Record 29 of Set 3 | gravdal
# Processing Record 30 of Set 3 | saldanha
# Processing Record 31 of Set 3 | butaritari
# Processing Record 32 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 3 | umea
# Processing Record 34 of Set 3 | faanui
# Processing Record 35 of Set 3 | hambantota
# Processing Record 36 of Set 3 | nabire
# Processing Record 37 of Set 3 | taman
# Processing Record 38 of Set 3 | asau
# Processing Record 39 of Set 3 | jinchang
# Processing Record 40 of Set 3 | longyearbyen
# Processing Record 41 of Set 3 | isangel
# Processing Record 42 of Set 3 | nunoa
# Processing Record 43 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 3 | sioux lookout
# Processing Record 45 of Set 3 | kiunga
# Processing Record 46 of Set 3 | russell
# Processing Record 47 of Set 3 | saint-augustin
# Processing Record 48 of Set 3 | tefe
# Processing Record 49 of Set 3 | takanabe
# Processing Record 50 of Set 3 | wynyard
# Processing Record 1 of Set 4 | khatanga
# Processing Record 2 of Set 4 | sabha
# Processing Record 3 of Set 4 | elliot lake
# Processing Record 4 of Set 4 | lengshuitan
# Processing Record 5 of Set 4 | pochutla
# Processing Record 6 of Set 4 | rocha
# Processing Record 7 of Set 4 | chebenki
# Processing Record 8 of Set 4 | praia da vitoria
# Processing Record 9 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 10 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 4 | hirara
# Processing Record 12 of Set 4 | uige
# Processing Record 13 of Set 4 | banikoara
# Processing Record 14 of Set 4 | eastlake
# Processing Record 15 of Set 4 | miyako
# Processing Record 16 of Set 4 | erzin
# Processing Record 17 of Set 4 | shaunavon
# Processing Record 18 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 4 | kushmurun
# Processing Record 20 of Set 4 | bredasdorp
# Processing Record 21 of Set 4 | bilma
# Processing Record 22 of Set 4 | geraldton
# Processing Record 23 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 24 of Set 4 | sorong
# Processing Record 25 of Set 4 | cayenne
# Processing Record 26 of Set 4 | lavrentiya
# Processing Record 27 of Set 4 | pascagoula
# Processing Record 28 of Set 4 | la victoria
# Processing Record 29 of Set 4 | madarounfa
# Processing Record 30 of Set 4 | les cayes
# Processing Record 31 of Set 4 | sonoita
# Processing Record 32 of Set 4 | pangody
# Processing Record 33 of Set 4 | channel-port aux basques
# Processing Record 34 of Set 4 | bengkulu
# Processing Record 35 of Set 4 | porbandar
# Processing Record 36 of Set 4 | vao
# Processing Record 37 of Set 4 | susanville
# Processing Record 38 of Set 4 | cordoba
# Processing Record 39 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 4 | yerbogachen
# Processing Record 41 of Set 4 | richards bay
# Processing Record 42 of Set 4 | alofi
# Processing Record 43 of Set 4 | diego de almagro
# Processing Record 44 of Set 4 | valdivia
# Processing Record 45 of Set 4 | ternate
# Processing Record 46 of Set 4 | broome
# Processing Record 47 of Set 4 | nizhniy kuranakh
# Processing Record 48 of Set 4 | pombia
# Processing Record 49 of Set 4 | nanortalik
# Processing Record 50 of Set 4 | hovd
# Processing Record 1 of Set 5 | boende
# Processing Record 2 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 3 of Set 5 | olafsvik
# Processing Record 4 of Set 5 | hokitika
# Processing Record 5 of Set 5 | tarko-sale
# Processing Record 6 of Set 5 | ostrovnoy
# Processing Record 7 of Set 5 | bac lieu
# Processing Record 8 of Set 5 | college
# Processing Record 9 of Set 5 | catamarca
# Processing Record 10 of Set 5 | cozumel
# Processing Record 11 of Set 5 | kovur
# Processing Record 12 of Set 5 | roald
# Processing Record 13 of Set 5 | taltal
# Processing Record 14 of Set 5 | tarabuco
# Processing Record 15 of Set 5 | bethel
# Processing Record 16 of Set 5 | palana
# Processing Record 17 of Set 5 | wasilla
# Processing Record 18 of Set 5 | seoul
# Processing Record 19 of Set 5 | castro
# Processing Record 20 of Set 5 | hirtshals
# Processing Record 21 of Set 5 | tubruq
# City not found. Skipping...
# Processing Record 22 of Set 5 | adrar
# Processing Record 23 of Set 5 | juliaca
# Processing Record 24 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 25 of Set 5 | mattawa
# Processing Record 26 of Set 5 | zyryanka
# Processing Record 27 of Set 5 | kamina
# Processing Record 28 of Set 5 | camacha
# Processing Record 29 of Set 5 | mookane
# Processing Record 30 of Set 5 | luderitz
# Processing Record 31 of Set 5 | petropavlovka
# Processing Record 32 of Set 5 | dera din panah
# City not found. Skipping...
# Processing Record 33 of Set 5 | yinchuan
# Processing Record 34 of Set 5 | kyren
# Processing Record 35 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 36 of Set 5 | sire
# Processing Record 37 of Set 5 | garissa
# Processing Record 38 of Set 5 | kipini
# Processing Record 39 of Set 5 | cidreira
# Processing Record 40 of Set 5 | kyenjojo
# Processing Record 41 of Set 5 | marquette
# Processing Record 42 of Set 5 | poya
# Processing Record 43 of Set 5 | lahijan
# Processing Record 44 of Set 5 | koryukivka
# Processing Record 45 of Set 5 | kuytun
# Processing Record 46 of Set 5 | zhuhai
# Processing Record 47 of Set 5 | saint-joseph
# Processing Record 48 of Set 5 | airai
# Processing Record 49 of Set 5 | zabid
# Processing Record 50 of Set 5 | eldorado
# Processing Record 1 of Set 6 | bollnas
# Processing Record 2 of Set 6 | portland
# Processing Record 3 of Set 6 | vallenar
# Processing Record 4 of Set 6 | gamba
# Processing Record 5 of Set 6 | chicama
# Processing Record 6 of Set 6 | meulaboh
# Processing Record 7 of Set 6 | tabuk
# Processing Record 8 of Set 6 | touros
# Processing Record 9 of Set 6 | henties bay
# Processing Record 10 of Set 6 | torbay
# Processing Record 11 of Set 6 | georgetown
# Processing Record 12 of Set 6 | pisco
# Processing Record 13 of Set 6 | westport
# Processing Record 14 of Set 6 | kuminskiy
# Processing Record 15 of Set 6 | gao
# Processing Record 16 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 17 of Set 6 | sonqor
# Processing Record 18 of Set 6 | ayagoz
# Processing Record 19 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 20 of Set 6 | kenai
# Processing Record 21 of Set 6 | ronneby
# Processing Record 22 of Set 6 | agapovka
# Processing Record 23 of Set 6 | lasa
# Processing Record 24 of Set 6 | maloshuyka
# City not found. Skipping...
# Processing Record 25 of Set 6 | ponta do sol
# Processing Record 26 of Set 6 | lugoba
# Processing Record 27 of Set 6 | antiguo morelos
# Processing Record 28 of Set 6 | turayf
# Processing Record 29 of Set 6 | severo-yeniseyskiy
# Processing Record 30 of Set 6 | datong
# Processing Record 31 of Set 6 | puerto el triunfo
# Processing Record 32 of Set 6 | akdepe
# Processing Record 33 of Set 6 | plettenberg bay
# Processing Record 34 of Set 6 | sao joao da barra
# Processing Record 35 of Set 6 | grindavik
# Processing Record 36 of Set 6 | turukhansk
# Processing Record 37 of Set 6 | mayskiy
# Processing Record 38 of Set 6 | port macquarie
# Processing Record 39 of Set 6 | venice
# Processing Record 40 of Set 6 | jieshi
# Processing Record 41 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 6 | gritsovskiy
# Processing Record 43 of Set 6 | buchanan
# Processing Record 44 of Set 6 | nishihara
# Processing Record 45 of Set 6 | kodigenahalli
# Processing Record 46 of Set 6 | ulkan
# Processing Record 47 of Set 6 | bereda
# Processing Record 48 of Set 6 | severo-kurilsk
# Processing Record 49 of Set 6 | massakory
# Processing Record 50 of Set 6 | otavi
# Processing Record 1 of Set 7 | killybegs
# Processing Record 2 of Set 7 | santa maria
# Processing Record 3 of Set 7 | norwich
# Processing Record 4 of Set 7 | peterhead
# Processing Record 5 of Set 7 | grand gaube
# Processing Record 6 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 7 | mechoacan
# City not found. Skipping...
# Processing Record 8 of Set 7 | clyde river
# Processing Record 9 of Set 7 | vestmannaeyjar
# Processing Record 10 of Set 7 | cam pha
# City not found. Skipping...
# Processing Record 11 of Set 7 | hami
# Processing Record 12 of Set 7 | haapiti
# Processing Record 13 of Set 7 | san jeronimo
# Processing Record 14 of Set 7 | beinamar
# Processing Record 15 of Set 7 | rincon
# Processing Record 16 of Set 7 | bubaque
# Processing Record 17 of Set 7 | the pas
# Processing Record 18 of Set 7 | magdalena
# Processing Record 19 of Set 7 | demba
# Processing Record 20 of Set 7 | miri
# Processing Record 21 of Set 7 | sitka
# Processing Record 22 of Set 7 | sakakah
# Processing Record 23 of Set 7 | kangaatsiaq
# Processing Record 24 of Set 7 | tasiilaq
# Processing Record 25 of Set 7 | champerico
# Processing Record 26 of Set 7 | nha trang
# Processing Record 27 of Set 7 | conceicao do araguaia
# Processing Record 28 of Set 7 | constitucion
# Processing Record 29 of Set 7 | prince rupert
# Processing Record 30 of Set 7 | iquique
# Processing Record 31 of Set 7 | areia branca
# Processing Record 32 of Set 7 | waipawa
# Processing Record 33 of Set 7 | lokosovo
# Processing Record 34 of Set 7 | tuatapere
# Processing Record 35 of Set 7 | coahuayana
# Processing Record 36 of Set 7 | balakovo
# Processing Record 37 of Set 7 | irricana
# Processing Record 38 of Set 7 | belmonte
# Processing Record 39 of Set 7 | makakilo city
# Processing Record 40 of Set 7 | sumbe
# Processing Record 41 of Set 7 | luau
# Processing Record 42 of Set 7 | yar-sale
# Processing Record 43 of Set 7 | sukhumi
# Processing Record 44 of Set 7 | catabola
# Processing Record 45 of Set 7 | aksu
# Processing Record 46 of Set 7 | valparaiso
# Processing Record 47 of Set 7 | orotukan
# Processing Record 48 of Set 7 | stantsionno-oyashinskiy
# Processing Record 49 of Set 7 | dzerzhinskoye
# Processing Record 50 of Set 7 | joshimath
# Processing Record 1 of Set 8 | saint-georges
# Processing Record 2 of Set 8 | poum
# Processing Record 3 of Set 8 | dandong
# Processing Record 4 of Set 8 | nantucket
# Processing Record 5 of Set 8 | pokhara
# Processing Record 6 of Set 8 | katangli
# Processing Record 7 of Set 8 | labuhan
# Processing Record 8 of Set 8 | ambilobe
# Processing Record 9 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 10 of Set 8 | cayambe
# Processing Record 11 of Set 8 | mount gambier
# Processing Record 12 of Set 8 | san jose de buan
# Processing Record 13 of Set 8 | belyy yar
# Processing Record 14 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 15 of Set 8 | ixtapa
# Processing Record 16 of Set 8 | roswell
# Processing Record 17 of Set 8 | howard springs
# Processing Record 18 of Set 8 | prainha
# Processing Record 19 of Set 8 | baiquan
# Processing Record 20 of Set 8 | marienburg
# Processing Record 21 of Set 8 | maniitsoq
# Processing Record 22 of Set 8 | harnosand
# Processing Record 23 of Set 8 | ketchikan
# Processing Record 24 of Set 8 | manaus
# Processing Record 25 of Set 8 | viedma
# Processing Record 26 of Set 8 | takoradi
# Processing Record 27 of Set 8 | keetmanshoop
# Processing Record 28 of Set 8 | labuan
# Processing Record 29 of Set 8 | macaboboni
# City not found. Skipping...
# Processing Record 30 of Set 8 | radford
# Processing Record 31 of Set 8 | kidal
# Processing Record 32 of Set 8 | bandarbeyla
# Processing Record 33 of Set 8 | huarmey
# Processing Record 34 of Set 8 | scarborough
# Processing Record 35 of Set 8 | capim grosso
# Processing Record 36 of Set 8 | coihaique
# Processing Record 37 of Set 8 | bambanglipuro
# Processing Record 38 of Set 8 | okha
# Processing Record 39 of Set 8 | lazaro cardenas
# Processing Record 40 of Set 8 | maragogi
# Processing Record 41 of Set 8 | thompson
# Processing Record 42 of Set 8 | alexandria
# Processing Record 43 of Set 8 | kampong chhnang
# Processing Record 44 of Set 8 | dudinka
# Processing Record 45 of Set 8 | payo
# Processing Record 46 of Set 8 | port blair
# Processing Record 47 of Set 8 | crib point
# Processing Record 48 of Set 8 | cortez
# Processing Record 49 of Set 8 | la ronge
# Processing Record 50 of Set 8 | te anau
# Processing Record 1 of Set 9 | atlantis
# Processing Record 2 of Set 9 | eenhana
# Processing Record 3 of Set 9 | yambio
# Processing Record 4 of Set 9 | pevek
# Processing Record 5 of Set 9 | dillon
# Processing Record 6 of Set 9 | yokadouma
# Processing Record 7 of Set 9 | ferry pass
# Processing Record 8 of Set 9 | san quintin
# Processing Record 9 of Set 9 | amga
# Processing Record 10 of Set 9 | marzuq
# Processing Record 11 of Set 9 | kavieng
# Processing Record 12 of Set 9 | babu
# Processing Record 13 of Set 9 | karamea
# City not found. Skipping...
# Processing Record 14 of Set 9 | forio
# Processing Record 15 of Set 9 | staryy nadym
# Processing Record 16 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 9 | kamra
# Processing Record 18 of Set 9 | ancud
# Processing Record 19 of Set 9 | matamoros
# Processing Record 20 of Set 9 | kahului
# Processing Record 21 of Set 9 | souillac
# Processing Record 22 of Set 9 | leo
# Processing Record 23 of Set 9 | oksfjord
# Processing Record 24 of Set 9 | eyl
# Processing Record 25 of Set 9 | raudeberg
# Processing Record 26 of Set 9 | ende
# Processing Record 27 of Set 9 | santiago de chuco
# Processing Record 28 of Set 9 | kilakarai
# Processing Record 29 of Set 9 | oktyabrskaya
# City not found. Skipping...
# Processing Record 30 of Set 9 | murchison
# Processing Record 31 of Set 9 | eydhafushi
# Processing Record 32 of Set 9 | buala
# Processing Record 33 of Set 9 | niquelandia
# Processing Record 34 of Set 9 | conakry
# Processing Record 35 of Set 9 | lorengau
# Processing Record 36 of Set 9 | los llanos de aridane
# Processing Record 37 of Set 9 | vangaindrano
# Processing Record 38 of Set 9 | karratha
# Processing Record 39 of Set 9 | carballo
# Processing Record 40 of Set 9 | maura
# Processing Record 41 of Set 9 | comodoro rivadavia
# Processing Record 42 of Set 9 | cooma
# Processing Record 43 of Set 9 | qaqortoq
# Processing Record 44 of Set 9 | hamilton
# Processing Record 45 of Set 9 | seymchan
# Processing Record 46 of Set 9 | yomou
# Processing Record 47 of Set 9 | kichera
# Processing Record 48 of Set 9 | azovskaya
# Processing Record 49 of Set 9 | zabaykalsk
# Processing Record 50 of Set 9 | mutis
# Processing Record 1 of Set 10 | half moon bay
# Processing Record 2 of Set 10 | mackay
# Processing Record 3 of Set 10 | korla
# Processing Record 4 of Set 10 | dolinsk
# Processing Record 5 of Set 10 | udachnyy
# Processing Record 6 of Set 10 | nizwa
# Processing Record 7 of Set 10 | fioletovo
# Processing Record 8 of Set 10 | fortuna
# Processing Record 9 of Set 10 | makaryev
# Processing Record 10 of Set 10 | celendin
# Processing Record 11 of Set 10 | havoysund
# Processing Record 12 of Set 10 | ust-barguzin
# Processing Record 13 of Set 10 | moron
# Processing Record 14 of Set 10 | kuandian
# Processing Record 15 of Set 10 | verkhoyansk
# Processing Record 16 of Set 10 | luanda
# Processing Record 17 of Set 10 | tessalit
# Processing Record 18 of Set 10 | namtsy
# Processing Record 19 of Set 10 | vicuna
# Processing Record 20 of Set 10 | whitehorse
# Processing Record 21 of Set 10 | iracoubo
# Processing Record 22 of Set 10 | yamoussoukro
# Processing Record 23 of Set 10 | ajdabiya
# Processing Record 24 of Set 10 | lebowakgomo
# Processing Record 25 of Set 10 | kensington
# Processing Record 26 of Set 10 | freeport
# Processing Record 27 of Set 10 | mogadishu
# Processing Record 28 of Set 10 | sibolga
# Processing Record 29 of Set 10 | ayan
# Processing Record 30 of Set 10 | del rio
# Processing Record 31 of Set 10 | soyo
# Processing Record 32 of Set 10 | vikhorevka
# Processing Record 33 of Set 10 | marsa matruh
# Processing Record 34 of Set 10 | guanare
# Processing Record 35 of Set 10 | ihosy
# Processing Record 36 of Set 10 | jaque
# Processing Record 37 of Set 10 | ridgecrest
# Processing Record 38 of Set 10 | ladario
# Processing Record 39 of Set 10 | avera
# Processing Record 40 of Set 10 | sistranda
# Processing Record 41 of Set 10 | kamenka
# Processing Record 42 of Set 10 | cap malheureux
# Processing Record 43 of Set 10 | palmer
# Processing Record 44 of Set 10 | barra do bugres
# Processing Record 45 of Set 10 | bor
# Processing Record 46 of Set 10 | ambon
# Processing Record 47 of Set 10 | dundalk
# Processing Record 48 of Set 10 | chapais
# Processing Record 49 of Set 10 | guatire
# Processing Record 50 of Set 10 | nedjo
# Processing Record 1 of Set 11 | makueni
# Processing Record 2 of Set 11 | chara
# Processing Record 3 of Set 11 | leningradskiy
# Processing Record 4 of Set 11 | parry sound
# Processing Record 5 of Set 11 | feuchtwangen
# Processing Record 6 of Set 11 | ulladulla
# Processing Record 7 of Set 11 | finschhafen
# Processing Record 8 of Set 11 | manacor
# Processing Record 9 of Set 11 | koulikoro
# Processing Record 10 of Set 11 | brigantine
# Processing Record 11 of Set 11 | celestun
# Processing Record 12 of Set 11 | benicarlo
# Processing Record 13 of Set 11 | berlevag
# Processing Record 14 of Set 11 | novoshcherbinovskaya
# Processing Record 15 of Set 11 | grande prairie
# Processing Record 16 of Set 11 | nebbi
# Processing Record 17 of Set 11 | gat
# Processing Record 18 of Set 11 | sinjar
# Processing Record 19 of Set 11 | hammerfest
# Processing Record 20 of Set 11 | dayong
# Processing Record 21 of Set 11 | baytown
# Processing Record 22 of Set 11 | byron bay
# Processing Record 23 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 11 | mujiayingzi
# Processing Record 26 of Set 11 | praya
# Processing Record 27 of Set 11 | amapa
# Processing Record 28 of Set 11 | natal
# Processing Record 29 of Set 11 | north creek
# Processing Record 30 of Set 11 | kuala terengganu
# Processing Record 31 of Set 11 | cockburn town
# Processing Record 32 of Set 11 | gemena
# Processing Record 33 of Set 11 | ukiah
# Processing Record 34 of Set 11 | patea
# Processing Record 35 of Set 11 | pomabamba
# Processing Record 36 of Set 11 | sambava
# Processing Record 37 of Set 11 | ksenyevka
# City not found. Skipping...
# Processing Record 38 of Set 11 | dalvik
# Processing Record 39 of Set 11 | chimbote
# Processing Record 40 of Set 11 | litovko
# Processing Record 41 of Set 11 | kazerun
# Processing Record 42 of Set 11 | manavgat
# Processing Record 43 of Set 11 | flin flon
# Processing Record 44 of Set 11 | eldikan
# City not found. Skipping...
# Processing Record 45 of Set 11 | kerouane
# Processing Record 46 of Set 11 | methoni
# Processing Record 47 of Set 11 | garowe
# Processing Record 48 of Set 11 | manoel urbano
# Processing Record 49 of Set 11 | saint-pierre
# Processing Record 50 of Set 11 | dingli
# Processing Record 1 of Set 12 | aldan
# Processing Record 2 of Set 12 | kabo
# Processing Record 3 of Set 12 | imbituba
# Processing Record 4 of Set 12 | san cristobal
# Processing Record 5 of Set 12 | tombouctou
# Processing Record 6 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 7 of Set 12 | beisfjord
# Processing Record 8 of Set 12 | pasinler
# Processing Record 9 of Set 12 | barao de melgaco
# Processing Record 10 of Set 12 | mountain home
# Processing Record 11 of Set 12 | vezirkopru
# Processing Record 12 of Set 12 | neiafu
# Processing Record 13 of Set 12 | oktyabrskiy
# Processing Record 14 of Set 12 | botou
# Processing Record 15 of Set 12 | muros
# Processing Record 16 of Set 12 | zachagansk
# City not found. Skipping...
# Processing Record 17 of Set 12 | mayo
# Processing Record 18 of Set 12 | matay
# Processing Record 19 of Set 12 | tungor
# Processing Record 20 of Set 12 | skopin
# Processing Record 21 of Set 12 | yibin
# Processing Record 22 of Set 12 | kedrovyy
# Processing Record 23 of Set 12 | quatre cocos
# Processing Record 24 of Set 12 | padang
# Processing Record 25 of Set 12 | namibe
# Processing Record 26 of Set 12 | vanavara
# Processing Record 27 of Set 12 | paita
# Processing Record 28 of Set 12 | coalcoman
# City not found. Skipping...
# Processing Record 29 of Set 12 | rorvik
# Processing Record 30 of Set 12 | tayibe
# City not found. Skipping...
# Processing Record 31 of Set 12 | akom
# Processing Record 32 of Set 12 | san andres
# Processing Record 33 of Set 12 | dalhousie
# Processing Record 34 of Set 12 | hilter
# Processing Record 35 of Set 12 | warrenton
# Processing Record 36 of Set 12 | thinadhoo
# Processing Record 37 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 38 of Set 12 | muravlenko
# Processing Record 39 of Set 12 | anadyr
# Processing Record 40 of Set 12 | kracheh
# City not found. Skipping...
# Processing Record 41 of Set 12 | dakar
# Processing Record 42 of Set 12 | utete
# Processing Record 43 of Set 12 | empa
# City not found. Skipping...
# Processing Record 44 of Set 12 | marsabit
# Processing Record 45 of Set 12 | huanren
# Processing Record 46 of Set 12 | ureki
# Processing Record 47 of Set 12 | necochea
# Processing Record 48 of Set 12 | mehamn
# Processing Record 49 of Set 12 | cassilandia
# Processing Record 50 of Set 12 | deputatskiy
# Processing Record 1 of Set 13 | banda aceh
# Processing Record 2 of Set 13 | san luis
# Processing Record 3 of Set 13 | lar
# Processing Record 4 of Set 13 | blairmore
# Processing Record 5 of Set 13 | goianesia
# Processing Record 6 of Set 13 | kuching
# Processing Record 7 of Set 13 | chimoio
# Processing Record 8 of Set 13 | ranong
# Processing Record 9 of Set 13 | tsabong
# Processing Record 10 of Set 13 | nice
# Processing Record 11 of Set 13 | moree
# Processing Record 12 of Set 13 | hanzhong
# Processing Record 13 of Set 13 | buraydah
# Processing Record 14 of Set 13 | peniche
# Processing Record 15 of Set 13 | zhigansk
# Processing Record 16 of Set 13 | okhotsk
# Processing Record 17 of Set 13 | diffa
# Processing Record 18 of Set 13 | yining
# Processing Record 19 of Set 13 | kitob
# Processing Record 20 of Set 13 | mtwara
# Processing Record 21 of Set 13 | mount isa
# Processing Record 22 of Set 13 | rafaela
# Processing Record 23 of Set 13 | leshukonskoye
# Processing Record 24 of Set 13 | muli
# Processing Record 25 of Set 13 | reconquista
# Processing Record 26 of Set 13 | aberdeen
# Processing Record 27 of Set 13 | baykit
# Processing Record 28 of Set 13 | rolim de moura
# City not found. Skipping...
# Processing Record 29 of Set 13 | paithan
# Processing Record 30 of Set 13 | puerto colombia
# Processing Record 31 of Set 13 | cabatuan
# Processing Record 32 of Set 13 | pueblo nuevo
# Processing Record 33 of Set 13 | chebsara
# Processing Record 34 of Set 13 | pakxan
# Processing Record 35 of Set 13 | dauphin
# Processing Record 36 of Set 13 | keelung
# Processing Record 37 of Set 13 | urgut
# Processing Record 38 of Set 13 | esmeralda
# Processing Record 39 of Set 13 | san rafael
# Processing Record 40 of Set 13 | ambodifototra
# City not found. Skipping...
# Processing Record 41 of Set 13 | vila
# Processing Record 42 of Set 13 | vestmanna
# Processing Record 43 of Set 13 | piryion
# City not found. Skipping...
# Processing Record 44 of Set 13 | nyurba
# Processing Record 45 of Set 13 | sobolevo
# Processing Record 46 of Set 13 | kerema
# Processing Record 47 of Set 13 | beloha
# Processing Record 48 of Set 13 | mazeikiai
# Processing Record 49 of Set 13 | wuhu
# Processing Record 50 of Set 13 | yei
# Processing Record 1 of Set 14 | las cruces
# Processing Record 2 of Set 14 | buqayq
# City not found. Skipping...
# Processing Record 3 of Set 14 | zima
# Processing Record 4 of Set 14 | iqaluit
# Processing Record 5 of Set 14 | miraflores
# Processing Record 6 of Set 14 | svay rieng
# Processing Record 7 of Set 14 | murdochville
# Processing Record 8 of Set 14 | inhambane
# Processing Record 9 of Set 14 | kasungu
# Processing Record 10 of Set 14 | san patricio
# Processing Record 11 of Set 14 | derzhavinsk
# Processing Record 12 of Set 14 | husavik
# Processing Record 13 of Set 14 | ust-nera
# Processing Record 14 of Set 14 | watsa
# Processing Record 15 of Set 14 | westpunt
# City not found. Skipping...
# Processing Record 16 of Set 14 | bria
# Processing Record 17 of Set 14 | nouakchott
# Processing Record 18 of Set 14 | saint-francois
# Processing Record 19 of Set 14 | ryotsu
# Processing Record 20 of Set 14 | grand-santi
# Processing Record 21 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 22 of Set 14 | lingao
# Processing Record 23 of Set 14 | algiers
# Processing Record 24 of Set 14 | kieta
# Processing Record 25 of Set 14 | xining
# Processing Record 26 of Set 14 | japura
# Processing Record 27 of Set 14 | khorixas
# Processing Record 28 of Set 14 | jackson
# Processing Record 29 of Set 14 | bathsheba
# Processing Record 30 of Set 14 | dalbandin
# Processing Record 31 of Set 14 | duz
# City not found. Skipping...
# Processing Record 32 of Set 14 | izazi
# Processing Record 33 of Set 14 | dunedin
# Processing Record 34 of Set 14 | doume
# Processing Record 35 of Set 14 | porto belo
# Processing Record 36 of Set 14 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 37 of Set 14 | shache
# Processing Record 38 of Set 14 | ust-ishim
# Processing Record 39 of Set 14 | rawson
# Processing Record 40 of Set 14 | bagotville
# Processing Record 41 of Set 14 | nurota
# Processing Record 42 of Set 14 | lakhipur
# Processing Record 43 of Set 14 | bafoulabe
# Processing Record 44 of Set 14 | hereford
# Processing Record 45 of Set 14 | bhander
# Processing Record 46 of Set 14 | oktyabrskoye
# Processing Record 47 of Set 14 | zarubino
# Processing Record 48 of Set 14 | namatanai
# Processing Record 49 of Set 14 | coos bay
# Processing Record 50 of Set 14 | miles city
# Processing Record 1 of Set 15 | matara
# Processing Record 2 of Set 15 | kichmengskiy gorodok
# Processing Record 3 of Set 15 | port moresby
# Processing Record 4 of Set 15 | nisia floresta
# Processing Record 5 of Set 15 | shuyskoye
# Processing Record 6 of Set 15 | srednekolymsk
# Processing Record 7 of Set 15 | merauke
# Processing Record 8 of Set 15 | bucerias
# Processing Record 9 of Set 15 | bonavista
# Processing Record 10 of Set 15 | haapu
# City not found. Skipping...
# Processing Record 11 of Set 15 | ola
# Processing Record 12 of Set 15 | paranhos
# Processing Record 13 of Set 15 | san carlos de bariloche
# Processing Record 14 of Set 15 | road town
# Processing Record 15 of Set 15 | liberal
# Processing Record 16 of Set 15 | beidao
# Processing Record 17 of Set 15 | coruripe
# Processing Record 18 of Set 15 | terrasini
# Processing Record 19 of Set 15 | segou
# Processing Record 20 of Set 15 | port pirie
# Processing Record 21 of Set 15 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 15 | khartoum
# Processing Record 23 of Set 15 | srikakulam
# Processing Record 24 of Set 15 | tripoli
# Processing Record 25 of Set 15 | volsk
# -----------------------------
# Data Retrieval Complete

# %%
# Add the data to a new DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Hobart      AU -42.8794  147.3294     62.06        54          75
# 1      Kaitangata      NZ -46.2817  169.8464     51.85        88         100
# 2        Oussouye      SN  12.4850  -16.5469     75.61        89          99
# 3      Bang Rakam      TH  16.7585  100.1174     87.80        62          20
# 4          Dikson      RU  73.5069   80.5464     33.08        74         100
# 5          Lieksa      FI  63.3167   30.0167     49.32        81         100
# 6  Saint-Philippe      RE -21.3585   55.7679     74.79        80          37
# 7          Narsaq      GL  60.9167  -46.0500     39.42        84          45
# 8     Sao Gotardo      BR -19.3111  -46.0489     65.14        51          31
# 9          Kodiak      US  57.7900 -152.4072     54.91        71         100
#
#    Wind Speed Current Description
# 0        8.05       broken clouds
# 1        3.36     overcast clouds
# 2        1.83     overcast clouds
# 3        5.75          few clouds
# 4        5.50     overcast clouds
# 5       19.08     overcast clouds
# 6       14.63          light rain
# 7        3.38    scattered clouds
# 8        3.31    scattered clouds
# 9        6.91     overcast clouds

# %%
# Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
